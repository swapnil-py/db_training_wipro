-- %%
%python
print("hello")

-- %%
%sql
select 'hello from sql'

-- %%
%python
%pip

-- %%
CREATE CATALOG gizmobox

-- %%
SHOW CATALOGS

-- %%
CREATE SCHEMA IF NOT EXISTS gizmobox.landing

-- %%
CREATE SCHEMA IF NOT EXISTS gizmobox.bronze;
CREATE SCHEMA IF NOT EXISTS gizmobox.silver;
CREATE SCHEMA IF NOT EXISTS gizmobox.gold;

-- %%
CREATE VOLUME gizmobox.landing.operational_data

-- %%
%fs ls /Volumes/gizmobox/landing/operational_data/customers/

-- %%
select * from json.`/Volumes/gizmobox/landing/operational_data/customers`
